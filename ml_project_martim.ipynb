# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train_data.csv', sep = ',')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2019-12-30           31.0                              N    2020-01-01
# 1    2019-08-30           46.0                              N    2020-01-01
# 2    2019-12-06           40.0                              N    2020-01-01
# 3           NaN            NaN                            NaN    2020-01-01
# 4    2019-12-30           61.0                              N    2020-01-01
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                 0.00      1988.0  2019-12-31
# 1                       Y              1745.93      1973.0  2020-01-01
# 2                       N              1434.80      1979.0  2020-01-01
# 3                     NaN                  NaN         NaN         NaN
# 4                       N                  NaN      1958.0  2019-12-31
#
#      C-3 Date                  Carrier Name Carrier Type  Claim Identifier  \
# ...

# %%
# Gráfico 1: Gender vs Alternative Dispute Resolution (Média não aplicável, somente contagem)
print("Contagem de Alternative Dispute Resolution por Gênero:")
print(data.groupby('Gender')['Alternative Dispute Resolution'].value_counts())

# Gráfico 2: Gender vs Attorney/Representative (Média não aplicável, somente contagem)
print("\nContagem de Attorney/Representative por Gênero:")
print(data.groupby('Gender')['Attorney/Representative'].value_counts())

# Gráfico 3: Gender vs Average Weekly Wage (Média)
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Average Weekly Wage', data=data, ci=None)
plt.title('Média de Salário Semanal por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Média do Salário Semanal')
plt.show()

print("\nContagem de Average Weekly Wage por Gênero:")
print(data['Gender'].value_counts())

# Gráfico 4: Gender vs Carrier Type (Média não aplicável, somente contagem)
print("\nContagem de Carrier Type por Gênero:")
print(data.groupby('Gender')['Carrier Type'].value_counts())

# Gráfico 5: Gender vs Claim Injury Type (Média não aplicável, somente contagem)
print("\nContagem de Claim Injury Type por Gênero:")
print(data.groupby('Gender')['Claim Injury Type'].value_counts())

# Gráfico 6: Gender vs IME-4 Count (Média)
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='IME-4 Count', data=data, ci=None)
plt.title('Média de IME-4 Count por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Média de IME-4 Count')
plt.show()

print("\nContagem de IME-4 Count por Gênero:")
print(data['Gender'].value_counts())

# Gráfico 7: Gender vs Agreement Reached (Média não aplicável, somente contagem)
print("\nContagem de Agreement Reached por Gênero:")
print(data.groupby('Gender')['Agreement Reached'].value_counts())
# Out:
# Contagem de Alternative Dispute Resolution por Gênero:
# Gender  Alternative Dispute Resolution
# F       N                                 233941
#         Y                                    110
# M       N                                 332716
#         Y                                   2497
#         U                                      5
# U       N                                   4709
#         Y                                      2
# X       N                                     46
# Name: count, dtype: int64
#
# Contagem de Attorney/Representative por Gênero:
# Gender  Attorney/Representative
# F       N                          171699
#         Y                           62352
# M       N                          216648
#         Y                          118570
# U       N                            3940
#         Y                             771
# X       Y                              42
#         N                               4
# Name: count, dtype: int64
# ...

# %%
# Gráfico de histograma: Carrier Type vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Number of Dependents', hue='Carrier Type', multiple='stack', bins=20)
plt.title('Histograma entre Carrier Type e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()

# %%
# Gráfico 1: Average Weekly Wage vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.boxplot(x='Number of Dependents', y='Average Weekly Wage', data=data)
plt.title('Relação entre Salário Semanal Médio e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Salário Semanal Médio')
plt.show()
# Gráfico 5: Carrier Type vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.countplot(x='Number of Dependents', hue='Carrier Type', data=data)
plt.title('Relação entre Carrier Type e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()
# Gráfico 4: Age at Injury vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.boxplot(x='Number of Dependents', y='Age at Injury', data=data)
plt.title('Relação entre Idade no Momento da Lesão e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Idade no Momento da Lesão')
plt.show()

# Gráfico 2: Claim Injury Type vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.countplot(x='Number of Dependents', hue='Claim Injury Type', data=data)
plt.title('Relação entre Claim Injury Type e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()
# Gráfico 3: WCB Decision vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.countplot(x='Number of Dependents', hue='WCB Decision', data=data)
plt.title('Relação entre WCB Decision e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()
# Gráfico 6: Alternative Dispute Resolution vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.countplot(x='Number of Dependents', hue='Alternative Dispute Resolution', data=data)
plt.title('Relação entre Resolução Alternativa de Disputas e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()
# Gráfico 7: Gender vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.countplot(x='Number of Dependents', hue='Gender', data=data)
plt.title('Relação entre Gênero e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Contagem')
plt.show()
# Gráfico 8: First Hearing Date vs Número de Dependentes
plt.figure(figsize=(12, 6))
sns.boxplot(x='Number of Dependents', y='First Hearing Date', data=data)
plt.title('Relação entre Data da Primeira Audiência e Número de Dependentes')
plt.xlabel('Número de Dependentes')
plt.ylabel('Data da Primeira Audiência')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtrar os dados onde 'COVID-19 Indicator' é 'Y'
covid_yes = data[data['COVID-19 Indicator'] == 'Y']

# Gráfico: COVID-19 Indicator = Y vs Claim Injury Type
plt.figure(figsize=(12, 6))
sns.countplot(x='COVID-19 Indicator', hue='Claim Injury Type', data=covid_yes)
plt.title('Relação entre COVID-19 Indicator (Y) e Claim Injury Type')
plt.xlabel('COVID-19 Indicator')
plt.ylabel('Contagem')
plt.legend(title='Claim Injury Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtrar os dados onde 'COVID-19 Indicator' é 'Y'
covid_yes = data[data['COVID-19 Indicator'] == 'Y']

# Contar o número de ocorrências de 'Claim Injury Type' para os casos com 'COVID-19 Indicator' = 'Y'
covid_yes_claim_injury_counts = covid_yes['Claim Injury Type'].value_counts()

# Calcular a percentagem de cada tipo de lesão
total_claims = covid_yes_claim_injury_counts.sum()
covid_yes_claim_injury_percentage = (covid_yes_claim_injury_counts / total_claims) * 100

# Calcular a percentagem acumulada
covid_yes_claim_injury_cumulative_percentage = covid_yes_claim_injury_percentage.cumsum()

# Criar um DataFrame com as contagens, percentagens e percentagem acumulada
covid_yes_claim_injury_df = pd.DataFrame({
    'Count': covid_yes_claim_injury_counts,
    'Percentage': covid_yes_claim_injury_percentage,
    'Cumulative Percentage': covid_yes_claim_injury_cumulative_percentage
})

# Exibir o resultado
print("Claim Injury Type para casos onde COVID-19 Indicator = 'Y'")
print(covid_yes_claim_injury_df)
# Out:
# Claim Injury Type para casos onde COVID-19 Indicator = 'Y'
#                    Count  Percentage  Cumulative Percentage
# Claim Injury Type
# 2. NON-COMP        18621   67.661059              67.661059
# 4. TEMPORARY        6048   21.975946              89.637004
# 3. MED ONLY         2233    8.113804              97.750808
# 1. CANCELLED         391    1.420733              99.171542
# 8. DEATH             166    0.603176              99.774717
# 6. PPD NSL            32    0.116275              99.890992
# 5. PPD SCH LOSS       17    0.061771              99.952763
# 7. PTD                13    0.047237             100.000000

# %%
# Gráfico 1: Carrier Type vs Claim Injury Type
plt.figure(figsize=(12, 6))
sns.countplot(x='Carrier Type', hue='Claim Injury Type', data=data)
plt.title('Relação entre Carrier Type e Claim Injury Type')
plt.xlabel('Carrier Type')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Claim Injury Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Gráfico 2: Carrier Type vs Average Weekly Wage
plt.figure(figsize=(12, 6))
sns.boxplot(x='Carrier Type', y='Average Weekly Wage', data=data)
plt.title('Relação entre Carrier Type e Average Weekly Wage')
plt.xlabel('Carrier Type')
plt.ylabel('Average Weekly Wage')
plt.xticks(rotation=45)
plt.show()

# Gráfico 3: Carrier Type vs Attorney/Representative
plt.figure(figsize=(12, 6))
sns.countplot(x='Carrier Type', hue='Attorney/Representative', data=data)
plt.title('Relação entre Carrier Type e Attorney/Representative')
plt.xlabel('Carrier Type')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Attorney/Representative', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Criar uma tabela cruzada (crosstab) para contar a frequência de 'Carrier Type' em função de 'Attorney/Representative'
carrier_type_with_attorney_counts = pd.crosstab(data['Carrier Type'], data['Attorney/Representative'])

# Exibir os resultados
print(carrier_type_with_attorney_counts)
# Out:
# Attorney/Representative                           N      Y
# Carrier Type
# 1A. PRIVATE                                  209231  76137
# 2A. SIF                                       69835  41309
# 3A. SELF PUBLIC                               74180  47740
# 4A. SELF PRIVATE                              37996  14792
# 5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)       3      1
# 5C. SPECIAL FUND - POI CARRIER WCB MENANDS        2      3
# 5D. SPECIAL FUND - UNKNOWN                      349    674
# UNKNOWN                                         695   1079

# %%
# Gráfico 1: Média do salário semanal médio vs Attorney/Representative
plt.figure(figsize=(10, 6))
sns.barplot(x='Attorney/Representative', y='Average Weekly Wage', data=data, ci=None)
plt.title('Média do Salário Semanal Médio vs Attorney/Representative')
plt.xlabel('Attorney/Representative')
plt.ylabel('Média do Salário Semanal Médio')
plt.show()

# Gráfico 2: Média do salário semanal médio vs Claim Injury Type
plt.figure(figsize=(12, 6))
sns.barplot(x='Claim Injury Type', y='Average Weekly Wage', data=data, ci=None)
plt.title('Média do Salário Semanal Médio vs Claim Injury Type')
plt.xlabel('Claim Injury Type')
plt.ylabel('Média do Salário Semanal Médio')
plt.xticks(rotation=45)
plt.show()

# %%
# Criar uma tabela cruzada (crosstab) para contar a frequência de 'Claim Injury Type' em função de 'Attorney/Representative'
claim_injury_type_by_attorney = pd.crosstab(data['Claim Injury Type'], data['Attorney/Representative'])

# Exibir os resultados
print(claim_injury_type_by_attorney)
# Out:
# Attorney/Representative       N      Y
# Claim Injury Type
# 1. CANCELLED               7426   5051
# 2. NON-COMP              269969  21109
# 3. MED ONLY               47207  21699
# 4. TEMPORARY              63268  85239
# 5. PPD SCH LOSS            4279  44001
# 6. PPD NSL                   89   4122
# 7. PTD                        1     96
# 8. DEATH                     52    418

# %%
# Criar gráfico para visualizar a relação entre 'Alternative Dispute Resolution' e 'Claim Injury Type'
plt.figure(figsize=(12, 6))
sns.countplot(x='Attorney/Representative', hue='Claim Injury Type', data=data)
plt.title('Relação entre Attorney/Representative e Claim Injury Type')
plt.xlabel('Attorney/Representative')
plt.ylabel('Contagem')
plt.legend(title='Attorney/Representative', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
# Criar uma tabela cruzada (crosstab) para contar a frequência de 'Claim Injury Type' em função de 'Attorney/Representative'
claim_injury_type_by_attorney = pd.crosstab(data['Claim Injury Type'], data['Attorney/Representative'])

# Calcular a percentagem de cada valor no total para advogado e não advogado
claim_injury_type_percentage = claim_injury_type_by_attorney.apply(lambda x: x / x.sum() * 100, axis=1)

# Concatenar os valores absolutos com as percentagens
claim_injury_type_with_percentage = pd.concat([claim_injury_type_by_attorney, claim_injury_type_percentage], axis=1, keys=['Count', 'Percentage'])

# Exibir o resultado
print(claim_injury_type_with_percentage)
# Out:
#                           Count        Percentage
# Attorney/Representative       N      Y          N          Y
# Claim Injury Type
# 1. CANCELLED               7426   5051  59.517512  40.482488
# 2. NON-COMP              269969  21109  92.747992   7.252008
# 3. MED ONLY               47207  21699  68.509274  31.490726
# 4. TEMPORARY              63268  85239  42.602706  57.397294
# 5. PPD SCH LOSS            4279  44001   8.862883  91.137117
# 6. PPD NSL                   89   4122   2.113512  97.886488
# 7. PTD                        1     96   1.030928  98.969072
# 8. DEATH                     52    418  11.063830  88.936170

# %%
# Contar os valores únicos de 'Alternative Dispute Resolution' e suas frequências
adr_counts = data['Alternative Dispute Resolution'].value_counts()

# Exibir os resultados
print(adr_counts)
# Out:
# Alternative Dispute Resolution
# N    571412
# Y      2609
# U         5
# Name: count, dtype: int64

# %%
# Filtrar os dados onde 'Alternative Dispute Resolution' é 'Y'
adr_yes = data[data['Alternative Dispute Resolution'] == 'Y']

# Contar os valores únicos de 'Claim Injury Type' para os casos com ADR 'Y'
claim_injury_type_counts_adr_yes = adr_yes['Claim Injury Type'].value_counts()

# Exibir os resultados
print("Claim Injury Type when 'Alternative Dispute Resolution' == 'Y'")
print(claim_injury_type_counts_adr_yes)

# Calcular a percentagem de cada 'Claim Injury Type' quando 'Alternative Dispute Resolution' é 'Y'
claim_injury_type_percentage_adr_yes = (claim_injury_type_counts_adr_yes / claim_injury_type_counts_adr_yes.sum()) * 100

# Exibir as percentagens
print(claim_injury_type_percentage_adr_yes)
# Out:
# Claim Injury Type when 'Alternative Dispute Resolution' == 'Y'
# Claim Injury Type
# 2. NON-COMP     2590
# 1. CANCELLED      19
# Name: count, dtype: int64
# Claim Injury Type
# 2. NON-COMP     99.271752
# 1. CANCELLED     0.728248
# Name: count, dtype: float64

# %%
# Filtrar as linhas onde WCB Decision é igual a 1
wcb_decision_1_rows = data[data['WCB Decision'] == '-1']

# Exibir as primeiras linhas filtradas
print(wcb_decision_1_rows.head())
# Out:
# Empty DataFrame
# Columns: [Accident Date, Age at Injury, Alternative Dispute Resolution, Assembly Date, Attorney/Representative, Average Weekly Wage, Birth Year, C-2 Date, C-3 Date, Carrier Name, Carrier Type, Claim Identifier, Claim Injury Type, County of Injury, COVID-19 Indicator, District Name, First Hearing Date, Gender, IME-4 Count, Industry Code, Industry Code Description, Medical Fee Region, OIICS Nature of Injury Description, WCIO Cause of Injury Code, WCIO Cause of Injury Description, WCIO Nature of Injury Code, WCIO Nature of Injury Description, WCIO Part Of Body Code, WCIO Part Of Body Description, Zip Code, Agreement Reached, WCB Decision, Number of Dependents]
# Index: []

# %%
# Valores únicos de 'Carrier Type'
print("Carrier Type:", data['Carrier Type'].unique())

# Valores únicos de 'Claim Injury Type'
print("Claim Injury Type:", data['Claim Injury Type'].unique())

# Valores únicos de 'Medical Fee Region'
print("Medical Fee Region:", data['Medical Fee Region'].unique())

# Valores únicos de 'WCB Decision'
print("WCB Decision:", data['WCB Decision'].unique())
# Out:
# Carrier Type: ['1A. PRIVATE' nan '2A. SIF' '4A. SELF PRIVATE' '3A. SELF PUBLIC'
#  'UNKNOWN' '5D. SPECIAL FUND - UNKNOWN'
#  '5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)'
#  '5C. SPECIAL FUND - POI CARRIER WCB MENANDS']
# Claim Injury Type: ['2. NON-COMP' '4. TEMPORARY' nan '3. MED ONLY' '5. PPD SCH LOSS'
#  '6. PPD NSL' '1. CANCELLED' '8. DEATH' '7. PTD']
# Medical Fee Region: ['I' 'II' nan 'IV' 'UK' 'III']
# WCB Decision: [ 0 -1]

# %%
# Garantir que 'Accident Date' esteja no formato de data
data['Accident Date'] = pd.to_datetime(data['Accident Date'], errors='coerce')

# Criar uma nova coluna 'Month' que extrai o mês da data do acidente
data['Month'] = data['Accident Date'].dt.month

# Verificar valores nulos nas colunas relevantes
print(data[['WCIO Nature of Injury Description', 'Month']].isnull().sum())

# Filtrar para remover valores nulos
filtered_data = data.dropna(subset=['WCIO Nature of Injury Description', 'Month'])

# Contar a frequência de tipos de lesão por mês
plt.figure(figsize=(12, 8))
sns.countplot(x='Month', hue='WCIO Nature of Injury Description', data=filtered_data)
plt.title('WCIO Nature of Injury Description vs Month of Accident')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='WCIO Nature of Injury Description', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()
# Out:
# WCIO Nature of Injury Description    35102
# Month                                23134
# dtype: int64

# %%
# Agrupar por 'Month' e 'WCIO Nature of Injury Description' para contar a frequência
top_injuries_per_month = filtered_data.groupby(['Month', 'WCIO Nature of Injury Description']).size().reset_index(name='count')

# Ordenar por mês e contagem para obter as lesões mais frequentes em cada mês
top_injuries_per_month_sorted = top_injuries_per_month.sort_values(['Month', 'count'], ascending=[True, False])

# Obter as 5 lesões mais frequentes por mês
top_5_injuries_per_month = top_injuries_per_month_sorted.groupby('Month').head(5)

# Exibir o resultado
print(top_5_injuries_per_month)
# Out:
#      Month WCIO Nature of Injury Description  count
# 49     1.0                    STRAIN OR TEAR  12956
# 16     1.0                         CONTUSION   9844
# 48     1.0                    SPRAIN OR TEAR   4734
# 32     1.0                        LACERATION   3573
# 4      1.0  ALL OTHER SPECIFIC INJURIES, NOC   3167
# 104    2.0                    STRAIN OR TEAR  13428
# 69     2.0                         CONTUSION  10297
# 103    2.0                    SPRAIN OR TEAR   5107
# 86     2.0                        LACERATION   3494
# 58     2.0  ALL OTHER SPECIFIC INJURIES, NOC   3262
# 157    3.0                    STRAIN OR TEAR  12350
# 123    3.0                         CONTUSION   9107
# 124    3.0                          COVID-19   6193
# 156    3.0                    SPRAIN OR TEAR   4567
# 139    3.0                        LACERATION   3794
# 208    4.0                    STRAIN OR TEAR  10995
# 175    4.0                         CONTUSION   7310
# ...

# %%
# Filtrar os dados para remover valores nulos na coluna de lesões
filtered_data = data.dropna(subset=['WCIO Nature of Injury Description'])

# Contar as 5 lesões mais comuns
top_injuries = filtered_data['WCIO Nature of Injury Description'].value_counts().head(5)

# Exibir as 5 lesões mais comuns
print(top_injuries)
# Out:
# WCIO Nature of Injury Description
# STRAIN OR TEAR                      153373
# CONTUSION                           110717
# SPRAIN OR TEAR                       55789
# LACERATION                           47157
# ALL OTHER SPECIFIC INJURIES, NOC     36101
# Name: count, dtype: int64

# %%
# Substituir valores de 'SPRAIN OR TEAR' por 'STRAIN OR TEAR' (ou vice-versa, dependendo da sua escolha)
filtered_data['WCIO Nature of Injury Description'] = filtered_data['WCIO Nature of Injury Description'].replace('SPRAIN OR TEAR', 'STRAIN OR TEAR')

# Contar novamente as 5 lesões mais comuns após a unificação
top_injuries_unified = filtered_data['WCIO Nature of Injury Description'].value_counts().head(5)

# Exibir os resultados
print(top_injuries_unified)
# Out:
# WCIO Nature of Injury Description
# STRAIN OR TEAR                      209162
# CONTUSION                           110717
# LACERATION                           47157
# ALL OTHER SPECIFIC INJURIES, NOC     36101
# COVID-19                             25724
# Name: count, dtype: int64

# %%
# Garantir que a coluna 'Accident Date' esteja no formato de data
data['Accident Date'] = pd.to_datetime(data['Accident Date'], errors='coerce')

# Filtrar os dados para incluir apenas lesões relacionadas à COVID-19
covid_data = data[data['WCIO Nature of Injury Description'] == 'COVID-19']

# Remover registros com datas ausentes
covid_data = covid_data.dropna(subset=['Accident Date'])

# Criar o histograma das datas de acidentes relacionadas à COVID-19
plt.figure(figsize=(10, 6))
sns.histplot(covid_data['Accident Date'], bins=30, kde=False)
plt.title('Distribuição de Datas de Lesões por COVID-19')
plt.xlabel('Data do Acidente')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtrar os dados para incluir apenas lesões relacionadas à COVID-19
covid_data = data[data['WCIO Nature of Injury Description'] == 'COVID-19']

# Criar um gráfico de barras mostrando a relação entre COVID-19 e o resultado final (WCB Decision)
plt.figure(figsize=(10, 6))
sns.countplot(x='WCB Decision', data=covid_data)
plt.title('Relação entre COVID-19 e WCB Decision (Todo o Período)')
plt.xlabel('WCB Decision')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

# %%
# Verificar os valores únicos na coluna 'WCB Decision' para lesões de COVID-19
print(covid_data['WCB Decision'].unique())

# Contar a frequência de cada decisão
print(covid_data['WCB Decision'].value_counts())
# Out:
# [0]
# WCB Decision
# 0    25724
# Name: count, dtype: int64

# %%
# Verificar as decisões para casos que não são COVID-19
non_covid_data = data[data['WCIO Nature of Injury Description'] != 'COVID-19']

# Verificar valores únicos na coluna 'WCB Decision' para casos não-COVID
print(non_covid_data['WCB Decision'].unique())

# Contar a frequência de cada decisão para casos não-COVID
print(non_covid_data['WCB Decision'].value_counts())
# Out:
# [ 0 -1]
# WCB Decision
#  0    548302
# -1     19445
# Name: count, dtype: int64

# %%
# Exibir as primeiras linhas da coluna 'WCB Decision' junto com os seus códigos
print(data[['WCB Decision']].drop_duplicates())

# Verificar se há um mapeamento entre o texto "Not Work Related" e o código 0
data_with_decision_code = data[['WCB Decision']].dropna().drop_duplicates()
print(data_with_decision_code)
# Out:
#    WCB Decision
# 0             0
# 3            -1
#    WCB Decision
# 0             0
# 3            -1

# %%
# Definir as 5 lesões mais comuns após a unificação
common_injuries = ['STRAIN OR TEAR']

# Filtrar o dataset para conter apenas essas lesões
filtered_data = filtered_data[filtered_data['WCIO Nature of Injury Description'].isin(common_injuries)]

# Gráfico de barras para visualizar a relação entre lesões e tipo de trabalho
plt.figure(figsize=(12, 8))
sns.countplot(x='Industry Code Description', hue='WCIO Nature of Injury Description', data=filtered_data)
plt.title('Relação entre Tipo de Lesão e Tipo de Trabalho')
plt.xticks(rotation=45)
plt.legend(title='Tipo de Lesão', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


# Gráfico de boxplot para analisar a idade dos trabalhadores por tipo de lesão
plt.figure(figsize=(10, 6))
sns.boxplot(x='WCIO Nature of Injury Description', y='Age at Injury', data=filtered_data)
plt.title('Relação entre Tipo de Lesão e Idade dos Trabalhadores')
plt.xticks(rotation=45)
plt.show()

# %%
print(data[['Industry Code Description', 'WCIO Nature of Injury Description']].isnull().sum())

# Filtrar os dados para remover valores nulos
filtered_data = data.dropna(subset=['Industry Code Description', 'WCIO Nature of Injury Description'])

# Criar uma tabela cruzada para contar as ocorrências entre 'Industry Code Description' e 'WCIO Nature of Injury Description'
crosstab = pd.crosstab(filtered_data['Industry Code Description'], filtered_data['WCIO Nature of Injury Description'])

# Exibir a tabela crosstab gerada
print(crosstab)

# Visualizar a relação com um gráfico de calor (heatmap)
plt.figure(figsize=(12, 8))
sns.heatmap(crosstab, cmap='Blues', annot=False)
plt.title('Industry Code Description vs WCIO Nature of Injury Description')
plt.xlabel('WCIO Nature of Injury Description')
plt.ylabel('Industry Code Description')
plt.xticks(rotation=45)
plt.show()
# Out:
# Industry Code Description            29403
# WCIO Nature of Injury Description    35102
# dtype: int64
# WCIO Nature of Injury Description                   ADVERSE REACTION TO A VACCINATION OR INOCULATION  \
# Industry Code Description
# ACCOMMODATION AND FOOD SERVICES                                                                    7
# ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMENT...                                                 2
# AGRICULTURE, FORESTRY, FISHING AND HUNTING                                                         0
# ARTS, ENTERTAINMENT, AND RECREATION                                                                1
# CONSTRUCTION                                                                                       0
# EDUCATIONAL SERVICES                                                                               6
# FINANCE AND INSURANCE                                                                              5
# ...

# %%
# Verificar se há valores nulos na coluna 'Number of Dependents'
print(data['Number of Dependents'].isnull().sum())

# Remover valores nulos, se existirem
filtered_data = data.dropna(subset=['Number of Dependents'])

# Verificar a relação entre 'Attorney/Representative' e 'Number of Dependents' (média de dependentes)
sns.barplot(x='Attorney/Representative', y='Number of Dependents', data=filtered_data)
plt.title("Average Number of Dependents by Attorney/Representative")
plt.show()
# Out:
# 19445

# %%
# Verificar se há valores nulos na coluna 'Number of Dependents'
print(data['Number of Dependents'].isnull().sum())

# Remover valores nulos na coluna 'Number of Dependents' e 'Carrier Type'
filtered_data = data.dropna(subset=['Number of Dependents', 'Carrier Type'])

# Verificar a relação entre 'Carrier Type' e 'Number of Dependents' (média de dependentes)
plt.figure(figsize=(10, 6))
sns.barplot(x='Carrier Type', y='Number of Dependents', data=filtered_data)
plt.title("Average Number of Dependents by Carrier Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# 19445

# %%
data['Carrier Type'] = data['Carrier Type'].astype('category')

# Filtrando os dados para garantir que só consideramos valores não nulos e salários positivos
filtered_data = data[(data['Average Weekly Wage'].notnull()) & (data['Average Weekly Wage'] > 0)]

# Calculando a média do salário semanal agrupada por tipo de seguradora (Carrier Type)
average_wage_by_carrier = filtered_data.groupby('Carrier Type')['Average Weekly Wage'].mean()
print(average_wage_by_carrier)

# Visualizando a média dos salários semanais por tipo de seguradora
plt.figure(figsize=(10, 6))
sns.barplot(x='Carrier Type', y='Average Weekly Wage', data=filtered_data, palette='magma')
plt.xlabel('Carrier Type')
plt.ylabel('Average Weekly Wage')
plt.title('Average Weekly Wage by Carrier Type')
plt.xticks(rotation=45)  # Rotaciona os rótulos se houver muitos tipos de seguradora
plt.show()
# Out:
# Carrier Type
# 1A. PRIVATE                                    1210.057051
# 2A. SIF                                        1243.122691
# 3A. SELF PUBLIC                                1574.429537
# 4A. SELF PRIVATE                                906.020597
# 5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)            NaN
# 5C. SPECIAL FUND - POI CARRIER WCB MENANDS             NaN
# 5D. SPECIAL FUND - UNKNOWN                      817.368813
# UNKNOWN                                         677.360000
# Name: Average Weekly Wage, dtype: float64

# %%
# Garantindo que a coluna 'Attorney/Representative' esteja categorizada corretamente
data['Attorney/Representative'] = data['Attorney/Representative'].astype('category')

# Filtrando os dados para garantir que só consideramos valores não nulos e salários positivos
filtered_data = data[(data['Average Weekly Wage'].notnull()) & (data['Average Weekly Wage'] > 0)]

# Calculando a média do salário semanal agrupada pela presença de advogado/representante
average_wage_by_attorney = filtered_data.groupby('Attorney/Representative')['Average Weekly Wage'].mean()
print(average_wage_by_attorney)

# Visualizando a média dos salários semanais por presença de advogado/representante
plt.figure(figsize=(8, 6))
sns.barplot(x='Attorney/Representative', y='Average Weekly Wage', data=filtered_data, palette='viridis')
plt.xlabel('Attorney/Representative')
plt.ylabel('Average Weekly Wage')
plt.title('Average Weekly Wage by Attorney/Representative')
plt.show()
# Out:
# Attorney/Representative
# N    1197.049809
# Y    1321.481600
# Name: Average Weekly Wage, dtype: float64

# %%
# Comparando a média dos salários semanais por tipo de lesão e presença de advogado/representante
plt.figure(figsize=(12, 6))
sns.barplot(x='Claim Injury Type', y='Average Weekly Wage', hue='Attorney/Representative', data=filtered_data, palette='viridis')
plt.xlabel('Claim Injury Type')
plt.ylabel('Average Weekly Wage')
plt.title('Average Weekly Wage by Claim Injury Type and Attorney/Representative')
plt.xticks(rotation=45)
plt.show()

# %%
# Convertendo datas para o formato datetime
data['First Hearing Date'] = pd.to_datetime(data['First Hearing Date'], errors='coerce')

# Calculando o tempo para a primeira audiência (em dias)
data['Days to First Hearing'] = (data['First Hearing Date'] - data['C-2 Date']).dt.days

# Removendo valores nulos para esta análise
time_filtered_data = data[data['Days to First Hearing'].notnull()]

# Comparando o tempo médio de resolução (tempo para primeira audiência) por presença de advogado
plt.figure(figsize=(8, 6))
sns.barplot(x='Attorney/Representative', y='Days to First Hearing', data=time_filtered_data, palette='coolwarm')
plt.xlabel('Attorney/Representative')
plt.ylabel('Days to First Hearing')
plt.title('Time to First Hearing by Attorney/Representative')
plt.show()

# %%
# Comparando a frequência das decisões do WCB com e sem advogado/representante
plt.figure(figsize=(10, 6))
sns.countplot(x='WCB Decision', hue='Attorney/Representative', data=filtered_data, palette='Set2')
plt.xlabel('WCB Decision')
plt.ylabel('Count')
plt.title('WCB Decision by Attorney/Representative')
plt.xticks(rotation=45)
plt.show()

# %%
data.describe(include ='all').T
# Out:
#                                        count unique  \
# Accident Date                         570337   5539
# Age at Injury                       574026.0    NaN
# Alternative Dispute Resolution        574026      3
# Assembly Date                         593471   1096
# Attorney/Representative               574026      2
# Average Weekly Wage                 545375.0    NaN
# Birth Year                          544948.0    NaN
# C-2 Date                              559466   2475
# C-3 Date                              187245   1648
# Carrier Name                          574026   2046
# Carrier Type                          574026      8
# Claim Identifier                    593471.0    NaN
# County of Injury                      574026     63
# COVID-19 Indicator                    574026      2
# District Name                         574026      8
# First Hearing Date                    150798   1094
# Gender                                574026      4
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data.boxplot(column=['Age at Injury'])
plt.show()

# %%
data[data['Age at Injury']=='0.0']['Age at Injury'].values
# Out:
# array([], dtype=float64)

# %%
young_injury_cases = data[data['Age at Injury'] < 16]
young_injury_cases.head()
# Out:
#                   Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Injury Type
# 2. NON-COMP          2019-06-26            0.0                              N
# 2. NON-COMP          2019-12-28            0.0                              N
# 2. NON-COMP                 NaN            0.0                              N
# 2. NON-COMP                 NaN            0.0                              N
# 2. NON-COMP          2019-12-20            0.0                              N
#
#                   Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Injury Type
# 2. NON-COMP          2020-01-02                       N                  0.0
# 2. NON-COMP          2020-01-02                       N                  0.0
# 2. NON-COMP          2020-01-02                       Y                  0.0
# 2. NON-COMP          2020-01-02                       Y                  0.0
# ...

# %%
young_injury_cases.tail()
# Out:
#                   Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Injury Type
# 2. NON-COMP                 NaN            0.0                              N
# 2. NON-COMP                 NaN            0.0                              N
# 1. CANCELLED                NaN            0.0                              N
# 2. NON-COMP          2022-12-13            0.0                              N
# 2. NON-COMP          2022-11-19            0.0                              N
#
#                   Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Injury Type
# 2. NON-COMP          2022-12-30                       Y                  0.0
# 2. NON-COMP          2022-12-30                       Y                  0.0
# 1. CANCELLED         2022-12-30                       Y                  0.0
# 2. NON-COMP          2022-12-30                       N                  0.0
# ...

# %%
data.isna().sum()
# Out:
# Accident Date                          23134
# Age at Injury                          19445
# Alternative Dispute Resolution         19445
# Assembly Date                              0
# Attorney/Representative                19445
# Average Weekly Wage                    48096
# Birth Year                             48523
# C-2 Date                               34005
# C-3 Date                              406226
# Carrier Name                           19445
# Carrier Type                           19445
# Claim Identifier                           0
# County of Injury                       19445
# COVID-19 Indicator                     19445
# District Name                          19445
# First Hearing Date                    442673
# Gender                                 19445
# IME-4 Count                           460668
# Industry Code                          29403
# Industry Code Description              29403
# Medical Fee Region                     19445
# ...

# %%
young_injury_cases = data[data['Age at Injury'] > 65]
young_injury_cases.head()
# Out:
#                   Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Injury Type
# 3. MED ONLY          2019-12-26           67.0                              N
# 4. TEMPORARY         2019-12-26           70.0                              N
# 5. PPD SCH LOSS      2019-12-30           69.0                              N
# 2. NON-COMP          2019-12-16           77.0                              N
# 4. TEMPORARY         2019-12-24           72.0                              N
#
#                   Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Injury Type
# 3. MED ONLY          2020-01-01                       N                 0.00
# 4. TEMPORARY         2020-01-01                       N               346.86
# 5. PPD SCH LOSS      2020-01-01                       Y               781.40
# 2. NON-COMP          2020-01-01                       N                 0.00
# ...

# %%
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
data['C-2 Date'] = pd.to_datetime(data['C-2 Date'], errors='coerce')
data['Accident Date'] = pd.to_datetime(data['Accident Date'], errors='coerce')

# Calculate the difference in days between Accident Date and C-2 Date
data['Days to Report'] = (data['C-2 Date'] - data['Accident Date']).dt.days

# Display the summary statistics for Days to Report
print(data['Days to Report'].describe())

# Optional: Visualize the distribution of reporting times
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data['Days to Report'].dropna(), bins=30, kde=True)
plt.xlabel('Days to Report (C-2 Date - Accident Date)')
plt.title('Distribution of Days to Report')
plt.show()
# Out:
# count    557346.00000
# mean         70.35153
# std         511.63367
# min       -8842.00000
# 25%           5.00000
# 50%          10.00000
# 75%          27.00000
# max       21503.00000
# Name: Days to Report, dtype: float64

# %%
# Remover valores nulos nas colunas relevantes
filtered_data = data.dropna(subset=['Age at Injury', 'Claim Injury Type'])

# Criar faixas etárias em intervalos de 5 anos
bins = range(0, 100, 5)
labels = [f'{i}-{i+4}' for i in bins[:-1]]
filtered_data['Age Group'] = pd.cut(filtered_data['Age at Injury'], bins=bins, labels=labels, right=False)

# Criar gráfico de barras para visualizar a relação entre a idade e o resultado final
plt.figure(figsize=(12, 6))
sns.countplot(x='Age Group', hue='Claim Injury Type', data=filtered_data)
plt.title('Distribuição dos Resultados Finais (WCB Decision) por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Claim Injury Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Selecionar as colunas de datas e outras colunas solicitadas
date_columns = ['Accident Date', 'C-2 Date', 'C-3 Date', 'Assembly Date', 'First Hearing Date']
additional_columns = ['Attorney/Representative', 'Claim Injury Type']

# Filtrar as linhas que não têm valores nulos nessas colunas
non_null_dates = data[date_columns + additional_columns].dropna()

# Exibir as primeiras 20 linhas sem valores nulos
print(non_null_dates.head(5))
# Out:
#    Accident Date    C-2 Date    C-3 Date Assembly Date First Hearing Date  \
# 1     2019-08-30  2020-01-01  2020-01-14    2020-01-01         2020-02-21
# 17    2019-12-19  2020-01-01  2020-01-07    2020-01-01         2020-08-13
# 21    2019-09-15  2020-01-01  2020-01-03    2020-01-01         2020-03-06
# 27    2019-12-09  2020-01-01  2020-01-07    2020-01-01         2021-10-21
# 29    2019-12-18  2020-01-01  2019-12-31    2020-01-01         2021-04-20
#
#    Attorney/Representative Claim Injury Type
# 1                        Y      4. TEMPORARY
# 17                       Y       3. MED ONLY
# 21                       Y       2. NON-COMP
# 27                       Y   5. PPD SCH LOSS
# 29                       N      4. TEMPORARY

# %%
df_nulos = data[data['Age at Injury'].isnull()]

# Printar todas as linhas que possuem valores nulos nessa coluna
print(df_nulos)
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 3                NaN            NaN                            NaN
# 33               NaN            NaN                            NaN
# 37               NaN            NaN                            NaN
# 42               NaN            NaN                            NaN
# 51               NaN            NaN                            NaN
# ...              ...            ...                            ...
# 593465           NaN            NaN                            NaN
# 593466           NaN            NaN                            NaN
# 593468           NaN            NaN                            NaN
# 593469           NaN            NaN                            NaN
# 593470           NaN            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 3         2020-01-01                     NaN                  NaN         NaN
# ...

# %%
# Definir a proporção mínima de valores nulos para cada linha
threshold = 0.5 * data.shape[1]  # 70% do número de colunas

# Contar quantas linhas têm mais de 70% das colunas com valores nulos
rows_with_many_nulls = data[data.isnull().sum(axis=1) > threshold]

# Mostrar a quantidade de linhas com mais de 70% de nulos
print(f"Quantidade de linhas com mais de 50% de valores nulos: {rows_with_many_nulls.shape[0]}")

total_rows = data.shape[0]
print(f"Total de linhas no dataset: {total_rows}")
# Out:
# Quantidade de linhas com mais de 50% de valores nulos: 19445
# Total de linhas no dataset: 593471

# %%
# Remover valores nulos nas colunas relevantes
filtered_data = data.dropna(subset=['Age at Injury', 'Claim Injury Type'])

# Criar faixas etárias em intervalos de 5 anos
bins = range(0, 100, 5)
labels = [f'{i}-{i+4}' for i in bins[:-1]]
filtered_data['Age Group'] = pd.cut(filtered_data['Age at Injury'], bins=bins, labels=labels, right=False)

# Criar gráfico de barras para visualizar a relação entre faixas etárias e tipo de lesão
plt.figure(figsize=(12, 6))
sns.countplot(x='Age Group', hue='Claim Injury Type', data=filtered_data)
plt.title('Distribuição de Claim Injury Type por Faixa Etária (Agrupado de 5 em 5 anos)')
plt.xlabel('Faixa Etária')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.legend(title='Claim Injury Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
